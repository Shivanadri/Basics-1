# %% [markdown]
# ### Magic Commands

# %% [markdown]
# **%md,%sql,%python,%scala,%r, %run,%fs,%sh**

# %% [markdown]
# **dbutils**

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls('/')

# %%
dbutils.fs.head("/Volumes/basic_catalog/sales/salesdata/customers.csv",138)

# %%
# %fs head /Volumes/basic_catalog/sales/salesdata/customers.csv

# %%
cust_df = spark.read.csv("/Volumes/basic_catalog/sales/salesdata/customers.csv")
orders_df = spark.read.csv("/Volumes/basic_catalog/sales/salesdata/orders.csv")
display(cust_df)
display(orders_df)

# %%
display(cust_df.describe())
