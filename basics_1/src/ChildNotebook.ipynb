# %%
dbutils.widgets.text("orderStatus","")
status = dbutils.widgets.get("orderStatus")

# %%
df = spark.read.csv('/Volumes/basic_catalog/sales/salesdata/orders.csv', header = True)
df.filter(f"order_status = '{status}'").show()
