# %%
dbutils.widgets.combobox(name = 'orderStatus', defaultValue = 'CLOSED',
                         choices= ['CANCELED','PENDING_PAYMENT','PAYMENT_REVIEW','ON_HOLD','PROCESSING','SUSPECTED_FRAUD','PENDING','CLOSED','COMPLETE'], label = 'ORDER STATUS')

# %%
status = dbutils.widgets.get('orderStatus')
dbutils.notebook.run('./ChildNotebook', 100, arguments={'orderStatus': status})
